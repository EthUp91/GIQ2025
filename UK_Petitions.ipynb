# %%
import pandas as pd

df = pd.read_csv('UK_Petitions.csv')
df
# Out:
# C:\Users\danil\AppData\Local\Temp\ipykernel_11432\1461662256.py:3: DtypeWarning: Columns (11,17,18,28,29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('UK_Petitions.csv')
#                              created_at      id  \
# 0      2020-03-02 12:06:20.235000+00:00  300000
# 1      2020-03-03 11:21:56.566000+00:00  300005
# 2      2020-03-03 11:22:53.628000+00:00  300007
# 3      2020-03-03 11:23:13.336000+00:00  300008
# 4      2020-03-03 11:23:23.361000+00:00  300009
# ...                                 ...     ...
# 50461  2024-01-24 22:20:35.997000+00:00  655831
# 50462  2024-01-25 07:38:51.586000+00:00  655838
# 50463  2024-01-25 09:55:33.243000+00:00  655843
# 50464  2024-01-25 12:14:22.101000+00:00  655857
# 50465  2024-01-25 12:51:43.295000+00:00  655861
#
#                                               links.self  \
# 0      https://petition.parliament.uk/petitions/30000...
# ...

# %%
import pandas as pd

# Specify the columns you want to load
columns_to_load = [
    'action', 
    'background', 
    'additional_details',
    'state' 

]

# Load only the specified columns
df = pd.read_csv('UK_Petitions.csv', usecols=columns_to_load)

# Display the first few rows of the loaded DataFrame
df.head()
# Out:
#                                               action  \
# 0  Protect the Environment – support carbon neutr...
# 1  Bring Hailsham’s roads back to a their former ...
# 2  Give holiday caravan/lodge owners the same sta...
# 3  Increase the criteria for a successful referen...
# 4  Allow conference speakers to be able to speak ...
#
#                                           background  \
# 0  In November 2019, Members of the UK Youth Parl...
# 1  “My aim is to get Hailsham streets and roads b...
# 2  Owners of holiday caravans and lodges need the...
# 3  Referendums can and have been deeply divisive,...
# 4  As of right now, you require a Tier 5 visa to ...
#
#                                   additional_details     state
# 0  To preserve this world for the next generation...    closed
# 1  I am wanting to start a petition because the r...  rejected
# 2  As a multi-million pound consumer industry wit...    closed
# 3  I propose increasing the threshold to 60%+ of ...  rejected
# ...

# %%
df['content'] = df['action'] + df['background'] + df['additional_details']
df.head()
# Out:
#                                               action  \
# 0  Protect the Environment – support carbon neutr...
# 1  Bring Hailsham’s roads back to a their former ...
# 2  Give holiday caravan/lodge owners the same sta...
# 3  Increase the criteria for a successful referen...
# 4  Allow conference speakers to be able to speak ...
#
#                                           background  \
# 0  In November 2019, Members of the UK Youth Parl...
# 1  “My aim is to get Hailsham streets and roads b...
# 2  Owners of holiday caravans and lodges need the...
# 3  Referendums can and have been deeply divisive,...
# 4  As of right now, you require a Tier 5 visa to ...
#
#                                   additional_details     state  \
# 0  To preserve this world for the next generation...    closed
# 1  I am wanting to start a petition because the r...  rejected
# 2  As a multi-million pound consumer industry wit...    closed
# 3  I propose increasing the threshold to 60%+ of ...  rejected
# ...

# %%
columns_to_delete = [
    'action',
    'background',
    'additional_details']
    
# Drop the columns
df = df.drop(columns=columns_to_delete)
df.head()
# Out:
#       state                                            content
# 0    closed  Protect the Environment – support carbon neutr...
# 1  rejected  Bring Hailsham’s roads back to a their former ...
# 2    closed  Give holiday caravan/lodge owners the same sta...
# 3  rejected  Increase the criteria for a successful referen...
# 4  rejected  Allow conference speakers to be able to speak ...

# %%
df.iloc[1]['content']
# Out:
# 'Bring Hailsham’s roads back to a their former glory“My aim is to get Hailsham streets and roads back to their former glory with the help and support of the residents of the town. I really believe that this is easily fulfillable. I hope, the end result for Hailsham will be a happy and safe place to live as far as the community and roads go.I am wanting to start a petition because the roads in and around hailsham are a disgrace!. myself and more than 50% of residents of the town are no where near happy with our town \r\n\r\nI ride a motorcycle myself and this town is no way safe for me anymore let alone all the other road users'

# %%
df = df[df['state'].isin(['rejected', 'closed'])]
df
# Out:
#           state                                            content
# 0        closed  Protect the Environment – support carbon neutr...
# 1      rejected  Bring Hailsham’s roads back to a their former ...
# 2        closed  Give holiday caravan/lodge owners the same sta...
# 3      rejected  Increase the criteria for a successful referen...
# 4      rejected  Allow conference speakers to be able to speak ...
# ...         ...                                                ...
# 50457  rejected  Keep the 6 week holidaysKids or people in gene...
# 50458  rejected  Knighthoods for Kevin Sinfieid & Rob BurrowsAc...
# 50459  rejected  Pass a law on conscription.If a war is declare...
# 50462  rejected                                                NaN
# 50464  rejected  Make supermarkets change reduced products to h...
#
# [49144 rows x 2 columns]

# %%
df['label'] = df['state'].map({'rejected': 0, 'closed': 1})

# Count the occurrences of each state
state_counts = df['state'].value_counts()

# Display the counts
print(state_counts)
# Out:
# state
# rejected    37684
# closed      11460
# Name: count, dtype: int64

# %%
df = df.dropna(subset=['content'])
df
# Out:
#           state                                            content  label
# 0        closed  Protect the Environment – support carbon neutr...      1
# 1      rejected  Bring Hailsham’s roads back to a their former ...      0
# 2        closed  Give holiday caravan/lodge owners the same sta...      1
# 3      rejected  Increase the criteria for a successful referen...      0
# 4      rejected  Allow conference speakers to be able to speak ...      0
# ...         ...                                                ...    ...
# 50455  rejected  Reconsider the nips for the a20 sidcup bypass ...      0
# 50457  rejected  Keep the 6 week holidaysKids or people in gene...      0
# 50458  rejected  Knighthoods for Kevin Sinfieid & Rob BurrowsAc...      0
# 50459  rejected  Pass a law on conscription.If a war is declare...      0
# 50464  rejected  Make supermarkets change reduced products to h...      0
#
# [46465 rows x 3 columns]

# %%
df['label'] = df['state'].map({'rejected': 0, 'closed': 1})

# Count the occurrences of each state
state_counts = df['state'].value_counts()

# Display the counts
print(state_counts)
# Out:
# state
# rejected    35649
# closed      10816
# Name: count, dtype: int64
# C:\Users\danil\AppData\Local\Temp\ipykernel_43488\3338137738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['state'].map({'rejected': 0, 'closed': 1})

# %%
# Create a new column 'rejected' with 1 if state is 'rejected', else 0
df['rejected'] = (df['state'] == 'rejected').astype(int)

# Create a new column 'closed' with 1 if state is 'closed', else 0
df['closed'] = (df['state'] == 'closed').astype(int)

# Display the updated DataFrame
df.head()
# Out:
# C:\Users\danil\AppData\Local\Temp\ipykernel_43488\843028238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rejected'] = (df['state'] == 'rejected').astype(int)
# C:\Users\danil\AppData\Local\Temp\ipykernel_43488\843028238.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['closed'] = (df['state'] == 'closed').astype(int)
#       state                                            content  label  \
# 0    closed  Protect the Environment – support carbon neutr...      1
# ...

# %%
columns_to_delete = [
    'label',
    'state']
    
# Drop the columns
df = df.drop(columns=columns_to_delete)
df.head()
# Out:
#                                              content  rejected  closed
# 0  Protect the Environment – support carbon neutr...         0       1
# 1  Bring Hailsham’s roads back to a their former ...         1       0
# 2  Give holiday caravan/lodge owners the same sta...         0       1
# 3  Increase the criteria for a successful referen...         1       0
# 4  Allow conference speakers to be able to speak ...         1       0

# %% [markdown]
# # Bert-base-cased Model

# %%
import os
import pandas as pd
import numpy as np
import shutil
import sys
import tqdm.notebook as tq
from collections import defaultdict

import torch
import torch.nn as nn

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
from sklearn.model_selection import train_test_split
# split into train and test
df_train, df_test = train_test_split(df, random_state=1234, test_size=0.30, shuffle=True)
# split test into test and validation datasets
df_test, df_valid = train_test_split(df_test, random_state=1234, test_size=0.50, shuffle=True)

# %%
# Count the number of 1s in the 'rejected' column
rejected_count = df_train['rejected'].sum()

# Count the number of 1s in the 'closed' column
closed_count = df_train['closed'].sum()

print(f"Number of 1s in 'rejected': {rejected_count}")
print(f"Number of 1s in 'closed': {closed_count}")
# Out:
# Number of 1s in 'rejected': 24935
# Number of 1s in 'closed': 7590

# %%
# Hyperparameters
MAX_LEN = 256
TRAIN_BATCH_SIZE = 32
VALID_BATCH_SIZE = 32
TEST_BATCH_SIZE = 32
EPOCHS = 10
LEARNING_RATE = 1e-05

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
print(f"Train: {df_train.shape}, Test: {df_test.shape}, Valid: {df_valid.shape}")
# Out:
# Train: (32525, 3), Test: (6970, 3), Valid: (6970, 3)

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, df, tokenizer, max_len, target_list):
        self.tokenizer = tokenizer
        self.df = df
        self.title = list(df['content'])
        self.targets = self.df[target_list].values
        self.targets = self.targets.astype(float)

        self.max_len = max_len

    def __len__(self):
        return len(self.title)

    def __getitem__(self, index):
        title = str(self.title[index])
        title = " ".join(title.split())
        inputs = self.tokenizer.encode_plus(
            title,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
            
        
        )
        return {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten(),
            'token_type_ids': inputs["token_type_ids"].flatten(),
            'targets': torch.FloatTensor(self.targets[index]),
            'text': title
        }

# %%
target_list = list(df.columns)
target_list = target_list[1:]
target_list
# Out:
# ['rejected', 'closed']

# %%
train_dataset = CustomDataset(df_train, tokenizer, MAX_LEN, target_list)
valid_dataset = CustomDataset(df_valid, tokenizer, MAX_LEN, target_list)
test_dataset = CustomDataset(df_test, tokenizer, MAX_LEN, target_list)

# %%
# Data loaders
train_data_loader = torch.utils.data.DataLoader(train_dataset, 
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=0
)

val_data_loader = torch.utils.data.DataLoader(valid_dataset, 
    batch_size=VALID_BATCH_SIZE,
    shuffle=False,
    num_workers=0
)

test_data_loader = torch.utils.data.DataLoader(test_dataset, 
    batch_size=TEST_BATCH_SIZE,
    shuffle=False,
    num_workers=0
)

# %%
class BERTClass(torch.nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = BertModel.from_pretrained('bert-base-cased', return_dict=True)
        self.dropout = torch.nn.Dropout(0.2)
        self.linear = torch.nn.Linear(768, 2)

    def forward(self, input_ids, attn_mask, token_type_ids):
        output = self.bert_model(
            input_ids, 
            attention_mask=attn_mask, 
            token_type_ids=token_type_ids
        )
        output_dropout = self.dropout(output.pooler_output)
        output = self.linear(output_dropout)
        return output

model = BERTClass()

# # Freezing BERT layers: (tested, weaker convergence)
# for param in model.bert_model.parameters():
#     param.requires_grad = False

model.to(device)
# Out:
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# Sum the values in the 'rejected' and 'closed' columns
rejected_count = df_train['rejected'].sum()
closed_count = df_train['closed'].sum()

# Print the results
print(f"Number of '1's in 'rejected' column: {rejected_count}")
print(f"Number of '1's in 'closed' column: {closed_count}")
# Out:
# Number of '1's in 'rejected' column: 24935
# Number of '1's in 'closed' column: 7590

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Assuming class_counts contains the counts for each class
class_counts = torch.tensor([24935, 7590], dtype=torch.float)
class_weights = 1.0 / class_counts  # Compute inverse class frequencies

# Normalize the weights
class_weights /= class_weights.sum()

# Ensure weights are on the correct device (e.g., GPU or CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_weights = class_weights.to(device)

# %%
# Define the loss function

def loss_fn(outputs, targets):
    return torch.nn.CrossEntropyLoss()(outputs, targets)

# %%
from transformers import AdamW

# define the optimizer
optimizer = AdamW(model.parameters(), lr = 1e-5)
# Out:
# C:\Users\danil\anaconda3\envs\multilabel\lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Training of the model for one epoch
def train_model(training_loader, model, optimizer):

    losses = []
    correct_predictions = 0
    num_samples = 0
    # set model to training mode (activate droput, batch norm)
    model.train()
    # initialize the progress bar
    loop = tq.tqdm(enumerate(training_loader), total=len(training_loader), 
                      leave=True, colour='steelblue')
    for batch_idx, data in loop:
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.float)

        # forward
        outputs = model(ids, mask, token_type_ids) # (batch,predict)=(32,8)
        loss = loss_fn(outputs, targets)
        losses.append(loss.item())
        # training accuracy, apply sigmoid, round (apply thresh 0.5)
        outputs = torch.sigmoid(outputs).cpu().detach().numpy().round()
        targets = targets.cpu().detach().numpy()
        correct_predictions += np.sum(outputs==targets)
        num_samples += targets.size   # total number of elements in the 2D array

        # backward
        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        # grad descent step
        optimizer.step()

        # Update progress bar
        #loop.set_description(f"")
        #loop.set_postfix(batch_loss=loss)

    # returning: trained model, model accuracy, mean loss
    return model, float(correct_predictions)/num_samples, np.mean(losses)

# %%
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Number of GPUs:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("Current GPU:", torch.cuda.current_device())
    print("GPU Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# Number of GPUs: 1
# Current GPU: 0
# GPU Name: NVIDIA GeForce RTX 3090 Ti

# %% [markdown]
# # Training

# %%
def eval_model(validation_loader, model, optimizer):
    losses = []
    correct_predictions = 0
    num_samples = 0
    # set model to eval mode (turn off dropout, fix batch norm)
    model.eval()

    with torch.no_grad():
        for batch_idx, data in enumerate(validation_loader, 0):
            ids = data['input_ids'].to(device, dtype = torch.long)
            mask = data['attention_mask'].to(device, dtype = torch.long)
            token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
            targets = data['targets'].to(device, dtype = torch.float)
            outputs = model(ids, mask, token_type_ids)

            loss = loss_fn(outputs, targets)
            losses.append(loss.item())

            # validation accuracy
            # add sigmoid, for the training sigmoid is in BCEWithLogitsLoss
            outputs = torch.sigmoid(outputs).cpu().detach().numpy().round()
            targets = targets.cpu().detach().numpy()
            correct_predictions += np.sum(outputs==targets)
            num_samples += targets.size   # total number of elements in the 2D array

    return float(correct_predictions)/num_samples, np.mean(losses)

# %%
import os

history = defaultdict(list)
best_accuracy = 0
best_model = None

for epoch in range(1, EPOCHS + 1):
    print(f'Epoch {epoch}/{EPOCHS}')
    model, train_acc, train_loss = train_model(train_data_loader, model, optimizer)
    val_acc, val_loss = eval_model(val_data_loader, model, optimizer)

    print(f'train_loss={train_loss:.4f}, val_loss={val_loss:.4f} train_acc={train_acc:.4f}, val_acc={val_acc:.4f}')

    history['train_acc'].append(train_acc)
    history['train_loss'].append(train_loss)
    history['val_acc'].append(val_acc)
    history['val_loss'].append(val_loss)

    # Save the model for the current epoch
    model_name = f"UK_Petitions_Model-bert-base-Cased-{epoch}epoch{'s' if epoch > 1 else ''}"
    torch.save(model.state_dict(), model_name)
# Out:
# Epoch 1/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.3885, val_loss=0.4252 train_acc=0.8302, val_acc=0.8122
# Epoch 2/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.2969, val_loss=0.3290 train_acc=0.8784, val_acc=0.8651
# Epoch 3/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.2350, val_loss=0.3540 train_acc=0.9076, val_acc=0.8623
# Epoch 4/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.1724, val_loss=0.5426 train_acc=0.9367, val_acc=0.8056
# Epoch 5/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.1279, val_loss=0.4777 train_acc=0.9561, val_acc=0.8552
# Epoch 6/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.0973, val_loss=0.5922 train_acc=0.9707, val_acc=0.8511
# Epoch 7/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# train_loss=0.0767, val_loss=0.7043 train_acc=0.9786, val_acc=0.8412
# Epoch 8/10
#   0%|          | 0/1017 [00:00<?, ?it/s]
# ...

# %% [markdown]
# #Need-1-epoch

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 8)
plt.plot(history['train_acc'], label='train accuracy', marker='o', markersize=4)
plt.plot(history['val_acc'], label='validation accuracy', marker='o', markersize=4)
plt.title('Training history')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1])
#plt.grid()

plt.figure(figsize=(10, 8))
plt.plot(history['train_loss'], label='train loss', marker='o', markersize=4)
plt.plot(history['val_loss'], label='validation loss', marker='o', markersize=4)
plt.title('Training history')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
#plt.grid()

plt.show()

# %% [markdown]
# # Evaluation

# %%
# Loading the best model
model = BERTClass()
model.load_state_dict(torch.load('UK_Petitions_Model-bert-base-Cased-1epoch'))
model = model.to(device)
# Out:
# C:\Users\danil\AppData\Local\Temp\ipykernel_43488\1995634538.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
def get_predictions(model, data_loader, threshold=0.5):
    """
    Get predictions from the model.
    
    Args:
        model: Trained model for binary classification.
        data_loader: DataLoader for evaluation data.
        threshold: Probability threshold for predicting class 1.
    
    Returns:
        titles: List of titles from the data.
        predictions: Tensor of binary predictions (0 or 1).
        prediction_probs: Tensor of probabilities for class 1.
        target_values: Tensor of true labels.
    """
    
    model = model.eval()
    
    titles = []
    predictions = []
    prediction_probs = []
    target_values = []

    with torch.no_grad():
        for data in data_loader:
            title = data["text"]  # Fetch text from the batch
            ids = data["input_ids"].to(device, dtype=torch.long)
            mask = data["attention_mask"].to(device, dtype=torch.long)
            token_type_ids = data['token_type_ids'].to(device, dtype=torch.long)
            targets = data["targets"].to(device, dtype=torch.float)

            # Forward pass
            logits = model(ids, mask, token_type_ids)  # Logits shape: [batch_size, 1]
            probs = torch.sigmoid(logits).squeeze(dim=1).detach().cpu()  # Probabilities for class 1

            # Apply threshold to get binary predictions
            preds = (probs > threshold).int()

            titles.extend(title)  # Add batch titles to the list
            predictions.extend(preds.tolist())  # Convert tensor to list of integers
            prediction_probs.extend(probs.tolist())  # Convert tensor to list of floats
            target_values.extend(targets.cpu().tolist())  # Convert tensor to list of floats

    # Convert lists to tensors
    predictions = torch.tensor(predictions)
    prediction_probs = torch.tensor(prediction_probs)
    target_values = torch.tensor(target_values)

    return titles, predictions, prediction_probs, target_values

# %%
titile, predictions, prediction_probs, target_values = get_predictions(model, test_data_loader)

import torch
from sklearn.metrics import classification_report

# Assuming predictions and target_values are PyTorch tensors on the GPU
predictions_cpu = predictions.cpu().numpy()
target_values_cpu = target_values.cpu().numpy()

# Now, you can use the classification_report function
print(classification_report(target_values_cpu, predictions_cpu, target_names=target_list))
# Out:
#               precision    recall  f1-score   support
#
#     rejected       0.94      0.81      0.87      5378
#       closed       0.56      0.82      0.67      1592
#
#    micro avg       0.81      0.81      0.81      6970
#    macro avg       0.75      0.81      0.77      6970
# weighted avg       0.85      0.81      0.82      6970
#  samples avg       0.81      0.81      0.81      6970
# C:\Users\danil\anaconda3\envs\multilabel\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Tokens' Contribution Analysis

# %% [markdown]
# # 1. (Shap Value)

# %%
# Loading the best model
model = BERTClass()
model.load_state_dict(torch.load('UK_Petitions_Model-bert-base-Cased-1epoch'))
model = model.to(device)
# Out:
# C:\Users\danil\AppData\Local\Temp\ipykernel_43488\3650248363.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
def predict_sentiment(texts):
    if isinstance(texts, str):
        texts = [texts]
    elif isinstance(texts, np.ndarray):
        texts = texts.tolist()

    # Tokenize the input text
    tokenized = tokenizer(texts, return_tensors="pt", truncation=True, padding=True)
    tokenized = {key: value.to(device) for key, value in tokenized.items()}  # Move to GPU

    # Perform inference
    with torch.no_grad():
        logits = model(
            input_ids=tokenized["input_ids"],
            attention_mask=tokenized["attention_mask"]
        )
        probabilities = torch.softmax(logits, dim=-1)
    return probabilities.cpu().numpy()

# %%
# Iterate through titles and check for the word "---"
for i, title in enumerate(titles):
    if "crazy" in title.lower():  # Use .lower() to make the search case-insensitive
        print(f"'incompetent ' found in document {i}: {title}")
# Out:
# 'incompetent ' found in document 985: Remove single-use plastic bags from shops and supermarkets.To put a bill in place that will make MNC's (inc. shops and supermarkets) completely remove plastic bags from being sold when purchasing something and making companies replace these single-use bags with brown paper bags to reduce plastic waste/it's environmental impact.Studies have found that we not only consume crazy amounts of micro plastics per year (in which they are now found in placentas), but they are now in every location on Earth. To truly make a change and dent the plastic pandemic, the UK must take more action, especially since now most foreign countries who take our plastic for recycling are no longer doing so. If the UK eradicates plastic bags from being sold and replaces it with paper bags, it will be a small but effective step forward.
# ...

# %%
#Predict

class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = BertModel.from_pretrained('bert-base-cased', return_dict=True)
        self.dropout = nn.Dropout(0.2)
        self.linear = nn.Linear(768, 2)

    def forward(self, input_ids, attention_mask, token_type_ids=None):
        """
        Forward pass for the model.

        Args:
            input_ids: Tensor of input IDs.
            attention_mask: Tensor of attention masks.
            token_type_ids: Tensor of token type IDs (optional).
        """
        if token_type_ids is not None:
            output = self.bert_model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                token_type_ids=token_type_ids
            )
        else:
            output = self.bert_model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )
        pooled_output = self.dropout(output.pooler_output)
        logits = self.linear(pooled_output)
        return logits



def get_predictionsBef(model, data_loader, threshold=0.5, top_k=1):
    """
    Outputs predictions from the model based on a threshold and top-k values.
    """
    model = model.eval()
    
    titles = []
    predictions = []
    prediction_probs = []
    target_values = []

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Automatically detect device
    model = model.to(device)  # Ensure the model is on the correct device

    with torch.no_grad():
        for data in data_loader:
            title = data["text"]
            ids = data["input_ids"].to(device, dtype=torch.long)  # Move to device
            mask = data["attention_mask"].to(device, dtype=torch.long)  # Move to device
            token_type_ids = data.get("token_type_ids", None)
            if token_type_ids is not None:
                token_type_ids = token_type_ids.to(device, dtype=torch.long)  # Move to device if present
            targets = data["targets"].to(device, dtype=torch.float)  # Move to device

            # Call the model with the appropriate arguments
            logits = model(input_ids=ids, attention_mask=mask, token_type_ids=token_type_ids)

            # Process logits
            outputs = torch.sigmoid(logits).detach().cpu()

            # Ensure outputs have the correct shape (batch_size, num_classes)
            if outputs.dim() != 2:
                raise ValueError(f"Outputs tensor is not 2D! It is {outputs.dim()}D.")

            # Find indices of values above the threshold
            above_threshold = outputs > threshold

            # Get the indices of the top k values among those above the threshold
            topk_indices = torch.topk(outputs * above_threshold, k=top_k, dim=1).indices

            # Create a binary tensor with 1s at the top k indices
            preds = torch.zeros_like(outputs)
            preds.scatter_(1, topk_indices, 1)

            titles.extend(title)
            predictions.append(preds)
            prediction_probs.append(outputs)
            target_values.append(targets.cpu())  # Move targets back to CPU for aggregation

    predictions = torch.cat(predictions)
    prediction_probs = torch.cat(prediction_probs)
    target_values = torch.cat(target_values)

    return titles, predictions, prediction_probs, target_values


# Define threshold value
threshold = 0.5  # You can adjust this value based on your requirement

# Get the predictions for the entire dataset
titles, predictions, prediction_probs, target_values = get_predictionsBef(model, test_data_loader)

# For the first example in the dataset
first_text = titles[401]
predicted_labels = predictions[401].cpu().numpy()  # Get the prediction for the first text
prediction_probs_first = prediction_probs[401].cpu().numpy()  # Get the probabilities for the first text
actual_labels = target_values[401].cpu().numpy()  # Get the actual labels for the first text

# Assuming target_list contains the label names corresponding to the predicted indices
label_names = target_list  # You should define target_list as the names of your labels

# Get the predicted labels and their probabilities (only for those above the threshold)
predicted_label_indices = [i for i, prob in enumerate(prediction_probs_first) if prob > threshold]
predicted_labels_with_probs = [(label_names[i], prediction_probs_first[i]) for i in predicted_label_indices]

# Get the actual labels
actual_label_indices = [i for i, actual in enumerate(actual_labels) if actual == 1]
actual_labels = [label_names[i] for i in actual_label_indices]

# Display the first text, the predicted labels with probabilities, and the actual labels
print(f"Text: {first_text}")
print(f"Predicted Label: {predicted_labels_with_probs}")
print(f"Actual Label: {actual_labels}")
# Out:
# Text: Get the name of Jesus Christ banned as a curse word in public spaces.To recognise the name of Jesus Christ being used as a curse word, as an offence, in public spaces. I know many other Christian’s across the board feel the same but feel they would not get the support of the government. The further we move away from Christianity the more corrupt society becomes.This petition is because Over the years, the name of ‘Jesus Christ’ has been used as a curse word and as a way to degrade God! The name of Siddhartha Gautama who Buddhists worship, the many names of the Hindu gods, the name of Allah is not used as a curse word, why then, is the name of Jesus Christ readily available at the lips of those who do not respect or have any reverence for Christianity? Whilst many may not believe in Jesus Christ, his name deserves as much respect as other religions.
# Predicted Label: [('rejected', 0.77129287)]
# Actual Label: ['rejected']

# %%
i = df_test["content"].iloc[401]
i
# Out:
# 'Get the name of Jesus Christ banned as a curse word in public spaces.To recognise the name of Jesus Christ being used as a curse word, as an offence, in public spaces. \r\nI know many other Christian’s across the board feel the same but feel they would not get the support of the government.\r\nThe further we move away from Christianity the more corrupt society becomes.This petition is because Over the years, the name of ‘Jesus Christ’ has been used as a curse word and as a way to degrade God!\r\nThe name of Siddhartha Gautama who Buddhists worship, the many names of the Hindu gods, the name of Allah is not used as a curse word, why then, is the name of Jesus Christ readily available at the lips of those who do not respect or have any reverence for Christianity?\r\nWhilst many may not believe in Jesus Christ, his name deserves as much respect as other religions.'

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np

# Initialize SHAP explainer
explainer = shap.Explainer(predict_sentiment, tokenizer)

# Example text
input_text = [i]

# Compute SHAP values
shap_values = explainer(input_text)

# Convert SHAP values to NumPy array
shap_values_array = np.array(shap_values.values)

# Keep only words that increase the probability of rejection
shap_values_filtered = np.where(shap_values_array[:, :, 0] > 0, shap_values_array[:, :, 0], 0)

# Reconstruct the SHAP explanation object with only red words
shap_values_filtered = shap.Explanation(
    values=shap_values_filtered, 
    base_values=shap_values.base_values[:, 0],  # Keep only class 0 base values
    data=shap_values.data
)

# Initialize SHAP visualization
shap.initjs()

# Capture the text plot with only red words
plt.figure()
shap.text_plot(shap_values_filtered)  # Only red words shown
plt.savefig("shap_red_words_plot.png", bbox_inches='tight', dpi=800)  # Save as PNG
plt.close()  # Close figure to prevent display
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Define threshold value
threshold = 0.5  # You can adjust this value based on your requirement

# Get the predictions for the entire dataset
titles, predictions, prediction_probs, target_values = get_predictionsBef(model, test_data_loader)

# For the first example in the dataset
first_text = titles[1429]
predicted_labels = predictions[1429].cpu().numpy()  # Get the prediction for the first text
prediction_probs_first = prediction_probs[1429].cpu().numpy()  # Get the probabilities for the first text
actual_labels = target_values[1429].cpu().numpy()  # Get the actual labels for the first text

# Assuming target_list contains the label names corresponding to the predicted indices
label_names = target_list  # You should define target_list as the names of your labels

# Get the predicted labels and their probabilities (only for those above the threshold)
predicted_label_indices = [i for i, prob in enumerate(prediction_probs_first) if prob > threshold]
predicted_labels_with_probs = [(label_names[i], prediction_probs_first[i]) for i in predicted_label_indices]

# Get the actual labels
actual_label_indices = [i for i, actual in enumerate(actual_labels) if actual == 1]
actual_labels = [label_names[i] for i in actual_label_indices]

# Display the first text, the predicted labels with probabilities, and the actual labels
print(f"Text: {first_text}")
print(f"Predicted Label: {predicted_labels_with_probs}")
print(f"Actual Label: {actual_labels}")
# Out:
# Text: We do not trust the government anymore. We need new leadership of the country.The government has repeatedly showed a lack of ability in dealing with the coronavirus pandemic. Either it is incompetent, or requires help. We want a cross-party leadership with FULL transparency, as the government is not able to lead this nation alone.Repeatedly, the government has shown an inability to provide consistent, reliable and trustworthy leadership in the face of the pandemic. We do not want to claim that the government is malicious. We do claim that the government is unable to do its job properly, and requires help. We need a cross-party leadership system where the country comes together and we can rebuild trust in our country, and the system.
# Predicted Label: [('rejected', 0.8644294)]
# Actual Label: ['rejected']

# %%
i = df_test["content"].iloc[1429]
i
# Out:
# 'We do not trust the government anymore. We need new leadership of the country.The government has repeatedly showed a lack of ability in dealing with the coronavirus pandemic. Either it is incompetent, or requires help. We want a cross-party leadership with FULL transparency, as the government is not able to lead this nation alone.Repeatedly, the government has shown an inability to provide consistent, reliable and trustworthy leadership in the face of the pandemic. \r\nWe do not want to claim that the government is malicious. We do claim that the government is unable to do its job properly, and requires help.\r\nWe need a cross-party leadership system where the country comes together and we can rebuild trust in our country, and the system.'

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np

# Initialize SHAP explainer
explainer = shap.Explainer(predict_sentiment, tokenizer)

# Example text
input_text = [i]

# Compute SHAP values
shap_values = explainer(input_text)

# Convert SHAP values to NumPy array
shap_values_array = np.array(shap_values.values)

# Keep only words that increase the probability of rejection
shap_values_filtered = np.where(shap_values_array[:, :, 0] > 0, shap_values_array[:, :, 0], 0)

# Reconstruct the SHAP explanation object with only red words
shap_values_filtered = shap.Explanation(
    values=shap_values_filtered, 
    base_values=shap_values.base_values[:, 0],  # Keep only class 0 base values
    data=shap_values.data
)

# Initialize SHAP visualization
shap.initjs()

# Capture the text plot with only red words
plt.figure()
shap.text_plot(shap_values_filtered)  # Only red words shown
plt.savefig("shap_red_words_plot.png", bbox_inches='tight', dpi=800)  # Save as PNG
plt.close()  # Close figure to prevent display
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Define threshold value
threshold = 0.5  # You can adjust this value based on your requirement

# Get the predictions for the entire dataset
titles, predictions, prediction_probs, target_values = get_predictionsBef(model, test_data_loader)

# For the first example in the dataset
first_text = titles[5846]
predicted_labels = predictions[5846].cpu().numpy()  # Get the prediction for the first text
prediction_probs_first = prediction_probs[5846].cpu().numpy()  # Get the probabilities for the first text
actual_labels = target_values[5846].cpu().numpy()  # Get the actual labels for the first text

# Assuming target_list contains the label names corresponding to the predicted indices
label_names = target_list  # You should define target_list as the names of your labels

# Get the predicted labels and their probabilities (only for those above the threshold)
predicted_label_indices = [i for i, prob in enumerate(prediction_probs_first) if prob > threshold]
predicted_labels_with_probs = [(label_names[i], prediction_probs_first[i]) for i in predicted_label_indices]

# Get the actual labels
actual_label_indices = [i for i, actual in enumerate(actual_labels) if actual == 1]
actual_labels = [label_names[i] for i in actual_label_indices]

# Display the first text, the predicted labels with probabilities, and the actual labels
print(f"Text: {first_text}")
print(f"Predicted Label: {predicted_labels_with_probs}")
print(f"Actual Label: {actual_labels}")
# Out:
# Text: Stop printing money—end inflation now.Stop sending money overseas (this includes crazy amounts to Ukraine), end the welfare state and simply — STOP SPENDING! This is the only way inflation will decrease.Excessive government spending has lead to high levels of inflation within the United Kingdom. Parliament spends money that they do not have—printing money devalues the pound and leads to inflation. Stop the excessive printing, stop spending money we DO NOT HAVE!
# Predicted Label: [('rejected', 0.89565176)]
# Actual Label: ['rejected']

# %%
i = df_test["content"].iloc[5846]
i
# Out:
# 'Stop printing money—end inflation now.Stop sending money overseas (this includes crazy amounts to Ukraine), end the welfare state and simply — STOP SPENDING! This is the only way inflation will decrease.Excessive government spending has lead to high levels of inflation within the United Kingdom. Parliament spends money that they do not have—printing money devalues the pound and leads to inflation. Stop the excessive printing, stop spending money we DO NOT HAVE!'

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np

# Initialize SHAP explainer
explainer = shap.Explainer(predict_sentiment, tokenizer)

# Example text
input_text = [i]

# Compute SHAP values
shap_values = explainer(input_text)

# Convert SHAP values to NumPy array
shap_values_array = np.array(shap_values.values)

# Keep only words that increase the probability of rejection
shap_values_filtered = np.where(shap_values_array[:, :, 0] > 0, shap_values_array[:, :, 0], 0)

# Reconstruct the SHAP explanation object with only red words
shap_values_filtered = shap.Explanation(
    values=shap_values_filtered, 
    base_values=shap_values.base_values[:, 0],  # Keep only class 0 base values
    data=shap_values.data
)

# Initialize SHAP visualization
shap.initjs()

# Capture the text plot with only red words
plt.figure()
shap.text_plot(shap_values_filtered)  # Only red words shown
plt.savefig("shap_red_words_plotNew.png", bbox_inches='tight', dpi=800)  # Save as PNG
plt.close()  # Close figure to prevent display
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
